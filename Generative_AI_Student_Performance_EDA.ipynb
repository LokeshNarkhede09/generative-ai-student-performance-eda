# %% [markdown]
# # Problem Statement
#
# The increasing use of Generative AI tools is changing how students learn and complete academic tasks. However, its impact on academic performance, study habits, and learning outcomes is not clearly understood. Therefore, this project aims to analyze student data to understand the effects of AI usage on education.

# %% [markdown]
# # Librareis
# - NumPy – Used for numerical computations and array operations.
# - Pandas – Used for data loading, cleaning, manipulation, and analysis.
# - Matplotlib – Used for creating basic charts and visualizations.
# - Seaborn – Used for creating attractive statistical visualizations and exploring data patterns.

# %% [markdown]
# # Columns and its meaning
# - Student_ID: Unique ID given to each student.
# - Major_Category: Student's field of study (e.g., Engineering, Business, Science).
# - Year_of_Study: Current academic year of the student (1st, 2nd, 3rd, etc.).
# - Pre_Semester_GPA: GPA before the semester started.
# - Weekly_GenAI_Hours: Number of hours spent using AI tools per week.
# - Primary_Use_Case: Main purpose for using AI (e.g., assignments, coding, research, studying).
# - Prompt_Engineering_Skill: Student's skill level in writing effective AI prompts.
# - Tool_Diversity: Number or variety of AI tools used by the student.
# - Paid_Subscription: Whether the student uses a paid AI service (Yes/No).
# - Traditional_Study_Hours: Hours spent studying without AI assistance.
# - Perceived_AI_Dependency: How much the student feels dependent on AI tools.
# - Institutional_Policy: College/university rules regarding AI usage.
# - Anxiety_Level_During_Exams: Student's anxiety or stress level during exams.
# - Post_Semester_GPA: GPA after the semester ended.
# - Skill_Retention_Score: Measure of how well the student remembers and retains learned concepts.
# - Burnout_Risk_Level: Risk of mental exhaustion or burnout due to workload and study habits.

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df=pd.read_csv(r"C:\Users\hp\Documents\Innomatics\EDA\AI Impact on Student Dataset.csv")
df
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          122902       Business        Junior             2.634
# 1          133815           Arts        Senior             3.548
# 2          140045            NaN      Freshman             3.659
# 3          126210       Business     Sophomore               NaN
# 4          145808           STEM        Senior             3.713
# ...           ...            ...           ...               ...
# 30895      132109            NaN        Senior             3.311
# 30896      123308           STEM      Graduate             3.375
# 30897      145806            NaN        Junior             3.266
# 30898      147179       Business        Junior             2.632
# 30899      133675     Humanities        Senior               NaN
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                    0.01        Summarizing_Reading                 Advanced
# ...

# %%
df.shape
# Out:
# (30900, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30900 entries, 0 to 30899
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  30900 non-null  int64
#  1   Major_Category              27810 non-null  object
#  2   Year_of_Study               30900 non-null  object
#  3   Pre_Semester_GPA            28428 non-null  float64
#  4   Weekly_GenAI_Hours          28428 non-null  float64
#  5   Primary_Use_Case            27810 non-null  object
#  6   Prompt_Engineering_Skill    30900 non-null  object
#  7   Tool_Diversity              29355 non-null  float64
#  8   Paid_Subscription           30900 non-null  object
#  9   Traditional_Study_Hours     28428 non-null  float64
#  10  Perceived_AI_Dependency     29355 non-null  float64
#  11  Institutional_Policy        27810 non-null  object
#  12  Anxiety_Level_During_Exams  29355 non-null  object
# ...

# %%
df.describe()
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   30900.000000      28428.000000        28428.000000    29355.000000
# mean   125035.440615          3.136602            8.792677        2.792369
# std     14462.508284          0.534018            9.851339        1.183502
# min    100001.000000         -1.998000            0.000000        1.000000
# 25%    112478.750000          2.826000            2.390000        2.000000
# 50%    125125.500000          3.207000            5.850000        3.000000
# 75%    137538.250000          3.521000           11.900000        4.000000
# max    150000.000000          5.490000          119.280000        5.000000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  Skill_Retention_Score
# count             28428.000000             29355.000000           28428.000000
# mean                 11.456555                 3.519366              75.747152
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Major_Category', 'Year_of_Study', 'Pre_Semester_GPA',
#        'Weekly_GenAI_Hours', 'Primary_Use_Case', 'Prompt_Engineering_Skill',
#        'Tool_Diversity', 'Paid_Subscription', 'Traditional_Study_Hours',
#        'Perceived_AI_Dependency', 'Institutional_Policy',
#        'Anxiety_Level_During_Exams', 'Post_Semester_GPA',
#        'Skill_Retention_Score', 'Burnout_Risk_Level'],
#       dtype='object')

# %% [markdown]
# # Check values of each columns

# %%
df['Major_Category'].unique()
# Out:
# array(['Business', 'Arts', nan, 'STEM', 'Medical', 'Humanities'],
#       dtype=object)

# %%
df['Major_Category'].isnull().sum()
# Out:
# np.int64(3090)

# %%
df['Weekly_GenAI_Hours'].unique()
# Out:
# array([1.000e-02,       nan, 1.034e+01, ..., 3.195e+01, 2.358e+01,
#        7.240e+01], shape=(3352,))

# %%
df['Weekly_GenAI_Hours'].isnull().sum()
# Out:
# np.int64(2472)

# %%
df['Primary_Use_Case'].unique()
# Out:
# array(['Summarizing_Reading', 'Copywriting/Drafting',
#        'Debugging/Troubleshooting', 'Direct_Answer_Generation',
#        'Ideation', nan], dtype=object)

# %%
df['Primary_Use_Case'].isnull().sum()
# Out:
# np.int64(3090)

# %%
df['Tool_Diversity'].unique()
# Out:
# array([ 5.,  1.,  2.,  3.,  4., nan])

# %%
df['Tool_Diversity'].isnull().sum()
# Out:
# np.int64(1545)

# %%
df['Perceived_AI_Dependency'].unique()
# Out:
# array([ 2.,  3.,  8.,  5.,  4.,  6.,  9., nan,  1.,  7., 10.])

# %%
df['Perceived_AI_Dependency'].isnull().sum()
# Out:
# np.int64(1545)

# %%
df['Institutional_Policy'].unique()
# Out:
# array(['Actively_Encouraged', nan, 'Allowed_With_Citation', 'Strict_Ban'],
#       dtype=object)

# %%
df['Institutional_Policy'].isnull().sum()
# Out:
# np.int64(3090)

# %%
for i in df['Traditional_Study_Hours'].unique():
    print(i)
# Out:
# 16.67
# 15.61
# 14.24
# 8.62
# 16.87
# 8.53
# 8.7
# 6.02
# 12.21
# 15.63
# nan
# 19.17
# 15.99
# 12.92
# 17.07
# 8.13
# 15.28
# 6.79
# 4.12
# 15.94
# 15.1
# 4.57
# 20.31
# 12.48
# 15.09
# 15.96
# 13.27
# 7.65
# 12.14
# 7.78
# 1.0
# 3.86
# 14.09
# 12.8
# 17.38
# 11.74
# 1.28
# 14.64
# 12.96
# 7.67
# 9.65
# 1.02
# 3.72
# 23.45
# 19.12
# 11.5
# 8.75
# 10.62
# 11.08
# 8.03
# 23.81
# 10.66
# 11.2
# 5.87
# 7.17
# 6.25
# 11.4
# 9.88
# 13.32
# 12.9
# 11.34
# 11.93
# 23.25
# 8.52
# 17.09
# 12.53
# 13.24
# 8.23
# 15.32
# 8.04
# 2.53
# 12.6
# 9.45
# 10.14
# 14.91
# 2.69
# 17.51
# 14.69
# 8.6
# 6.74
# 11.06
# 7.32
# 16.47
# 7.75
# 4.64
# 13.71
# 15.85
# 7.96
# 11.78
# 10.0
# 17.12
# 10.16
# 15.43
# 6.52
# 18.11
# 12.46
# 8.18
# 23.43
# 20.74
# 20.98
# 5.52
# 8.37
# 4.32
# 21.1
# 9.06
# 6.09
# 10.41
# 10.37
# 9.92
# 9.67
# 9.57
# 16.35
# 7.34
# 19.4
# 13.19
# 10.69
# 5.3
# 17.33
# 16.34
# 6.5
# 15.2
# 7.85
# 5.28
# 4.49
# 7.77
# 4.39
# 1.72
# 11.25
# 1.41
# 12.54
# 11.46
# 12.26
# 9.13
# 13.61
# ...

# %%
df['Traditional_Study_Hours'].isnull().sum()
# Out:
# np.int64(2472)

# %%
df['Anxiety_Level_During_Exams'].unique()
# Out:
# array(['3', '6', '2', '5', '7', '1', nan, '9', '4', '8', 'High', '11',
#        'low', '0', '10', '15', '13', '12', '14'], dtype=object)

# %%
df['Anxiety_Level_During_Exams'].isnull().sum()
# Out:
# np.int64(1545)

# %%
for i in df['Post_Semester_GPA'].unique():
    print(i)
# Out:
# 2.879
# 3.909
# 3.939
# 2.55
# 3.804
# 2.866
# 2.871
# nan
# 3.821
# 3.53
# 3.189
# 3.103
# 2.767
# 2.976
# 3.525
# 3.212
# 4
# 2.67
# 3.537
# 3.727
# 3.166
# 2.467
# 3.416
# 3.549
# 3.578
# 3.424
# 2.943
# 3.481
# 2.74
# 3.156
# 2.892
# 3.43
# 3.246
# 3.436
# 2.988
# 3.39
# 3.17
# 3.222
# 3.012
# 3.496
# 3.757
# 3.01
# 3.449
# 3.062
# 2.88
# 2.252
# 3.089
# 3.316
# 3.783
# 3.736
# 3.621
# 3.272
# 3.785
# 3.72
# 3.082
# 3.22
# 3.254
# 3.571
# 3.588
# 3.565
# 3.579
# 3.511
# 3.692
# 3.84
# 2.565
# 3.805
# 3.894
# 3.719
# 2.835
# 3.221
# 3.389
# 3.979
# 2.432
# 3.605
# 3.546
# 3.547
# 3.458
# 3.871
# 2.95
# 2.975
# 1.593
# 3.445
# 3.236
# 3.905
# 2.66
# 3.633
# 3.768
# 2.883
# 3.379
# 3.697
# 3.912
# 3.786
# 3.522
# 3.664
# 3.918
# 2.536
# 3.462
# 3.79
# 2.869
# 3.067
# 3.258
# 3.816
# 2.302
# 3.857
# 2.631
# 3.643
# 3.609
# 3.878
# 2.12
# 2.878
# 2.322
# 2.907
# 3.711
# 3.682
# 2.632
# 3.644
# 3.329
# 3.835
# 3.468
# 3.378
# 3.91
# 3.485
# 2.315
# 3.35
# 2.402
# 3.064
# 2.843
# 3.681
# ...

# %%
df['Post_Semester_GPA'].isnull().sum()
# Out:
# np.int64(2572)

# %%
for i in df['Skill_Retention_Score'].unique():
    print(i)
# Out:
# 82.37
# 51.3
# 72.59
# 62.92
# 100.0
# 59.89
# 77.36
# 96.68
# 68.62
# 96.75
# 83.7
# 80.47
# 85.94
# nan
# 89.38
# 98.86
# 67.19
# 81.19
# 77.92
# 86.84
# 57.36
# 56.65
# 76.89
# 66.31
# 92.56
# 70.63
# 72.56
# 83.53
# 83.82
# 66.67
# 71.16
# 69.33
# 92.82
# 67.58
# 51.97
# 92.88
# 46.18
# 72.31
# 98.18
# 72.64
# 76.7
# 64.66
# 89.2
# 74.49
# 70.55
# 80.64
# 55.96
# 79.65
# 64.78
# 81.24
# 80.34
# 90.71
# 84.31
# 85.56
# 61.07
# 85.5
# 78.59
# 68.17
# 82.58
# 76.68
# 66.93
# 56.38
# 61.18
# 72.97
# 77.28
# 71.41
# 72.09
# 99.9
# 63.21
# 68.55
# 62.96
# 77.6
# 79.27
# 77.7
# 88.32
# 74.15
# 75.05
# 82.11
# 67.44
# 67.08
# 84.34
# 50.43
# 67.52
# 91.67
# 73.44
# 71.05
# 79.18
# 79.36
# 75.2
# 69.37
# 75.59
# 68.0
# 63.65
# 52.55
# 84.36
# 60.67
# 84.05
# 60.43
# 73.65
# 70.27
# 79.07
# 70.65
# 90.57
# 84.33
# 88.83
# 67.66
# 71.21
# 82.94
# 71.36
# 69.69
# 76.48
# 75.5
# 73.9
# 78.08
# 57.39
# 89.28
# 78.09
# 92.3
# 48.53
# 76.76
# 83.43
# 97.54
# 68.75
# 64.13
# 88.94
# 78.28
# ...

# %%
df['Burnout_Risk_Level'].unique()
# Out:
# array(['Medium', 'Low', 'High', nan], dtype=object)

# %%
df['Burnout_Risk_Level'].isnull().sum()
# Out:
# np.int64(3090)

# %%
for i in df['Pre_Semester_GPA'].unique():
    print(i)
# Out:
# 2.634
# 3.548
# 3.659
# nan
# 3.713
# 2.54
# 3.849
# 2.876
# 2.713
# 3.166
# 3.626
# 3.186
# 2.485
# 2.616
# 2.86
# 3.066
# 3.384
# 3.489
# 2.985
# 3.203
# 2.986
# 2.314
# 3.855
# 3.136
# 3.143
# 2.99
# 2.956
# 3.253
# 2.686
# 3.032
# 2.755
# 3.337
# 2.964
# 3.394
# 3.74
# 3.391
# 2.981
# 3.4
# 2.868
# 3.142
# 3.342
# 3.486
# 3.049
# 3.477
# 2.911
# 2.419
# 2.22
# 2.888
# 3.449
# 3.402
# 3.317
# 3.084
# 3.302
# 3.459
# 2.961
# 3.118
# 3.001
# 3.422
# 3.426
# 3.414
# 3.397
# 3.233
# 3.568
# 3.437
# 2.019
# 3.475
# 3.47
# 3.395
# 3.879
# 3.647
# 3.637
# 3.482
# 2.906
# 3.038
# 3.367
# 3.511
# 1.967
# 3.714
# 3.603
# 3.63
# 3.684
# 3.005
# 2.998
# 1.634
# 3.195
# 3.701
# 2.952
# 3.92
# 3.617
# 3.653
# 2.831
# 2.929
# 3.455
# 3.756
# 3.044
# 3.666
# 3.457
# 3.184
# 2.578
# 3.259
# 2.487
# 2.773
# 2.885
# 3.026
# 3.274
# 2.14
# 3.715
# 2.429
# 3.271
# 3.199
# 2.054
# 2.614
# 2.284
# 2.893
# 3.556
# 3.49
# 2.424
# 3.505
# 3.054
# 3.03
# 3.533
# 3.328
# 3.786
# 3.875
# 3.576
# 3.149
# ...

# %%
df['Pre_Semester_GPA'].isnull().sum()
# Out:
# np.int64(2472)

# %% [markdown]
# ## Detect Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(123)

# %%
df[df.duplicated()]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 2591       114990           Arts      Freshman             3.004
# 2666       107232     Humanities      Freshman             2.713
# 3388       136493        Medical        Senior             3.688
# 4546       109289     Humanities      Freshman             2.900
# 5539       108937           STEM        Senior             3.534
# ...           ...            ...           ...               ...
# 30126      117699       Business      Freshman             3.451
# 30244      119071           STEM        Junior             2.969
# 30458      146259     Humanities      Freshman             3.856
# 30594      143983     Humanities        Junior             3.246
# 30890      113916       Business        Junior             2.827
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 2591                 2.82   Direct_Answer_Generation                 Advanced
# ...

# %% [markdown]
# ## Drop Duplicate

# %%
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Check missing Values

# %%
df.isnull().sum()
# Out:
# Student_ID                       0
# Major_Category                3088
# Year_of_Study                    0
# Pre_Semester_GPA              2472
# Weekly_GenAI_Hours            2472
# Primary_Use_Case              3089
# Prompt_Engineering_Skill         0
# Tool_Diversity                1545
# Paid_Subscription                0
# Traditional_Study_Hours       2472
# Perceived_AI_Dependency       1545
# Institutional_Policy          3089
# Anxiety_Level_During_Exams    1545
# Post_Semester_GPA             2571
# Skill_Retention_Score         2470
# Burnout_Risk_Level            3090
# dtype: int64

# %% [markdown]
# ## Handling missing Values

# %%
df.dropna(how='all')
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          122902       Business        Junior             2.634
# 1          133815           Arts        Senior             3.548
# 2          140045            NaN      Freshman             3.659
# 3          126210       Business     Sophomore               NaN
# 4          145808           STEM        Senior             3.713
# ...           ...            ...           ...               ...
# 30895      132109            NaN        Senior             3.311
# 30896      123308           STEM      Graduate             3.375
# 30897      145806            NaN        Junior             3.266
# 30898      147179       Business        Junior             2.632
# 30899      133675     Humanities        Senior               NaN
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                    0.01        Summarizing_Reading                 Advanced
# ...

# %% [markdown]
# ### Categorical Columns

# %%
df['Major_Category'] = df['Major_Category'].fillna(df['Major_Category'].mode()[0])

# %%
df['Primary_Use_Case'] = df['Primary_Use_Case'].fillna(df['Primary_Use_Case'].mode()[0])

# %%
df['Institutional_Policy'] = df['Institutional_Policy'].fillna(df['Institutional_Policy'].mode()[0])

# %%
df['Burnout_Risk_Level'] = df['Burnout_Risk_Level'].fillna(df['Burnout_Risk_Level'].mode()[0])

# %% [markdown]
# ### Numerical Column

# %%
df['Pre_Semester_GPA']=df['Pre_Semester_GPA'].fillna(df['Pre_Semester_GPA'].median())

# %%
df['Weekly_GenAI_Hours'] = df['Weekly_GenAI_Hours'].fillna(df['Weekly_GenAI_Hours'].median())

# %%
df['Tool_Diversity'] = df['Tool_Diversity'].fillna(df['Tool_Diversity'].median())

# %%
df['Traditional_Study_Hours'] = df['Traditional_Study_Hours'].fillna(df['Traditional_Study_Hours'].median())

# %%
df['Perceived_AI_Dependency'] = df['Perceived_AI_Dependency'].fillna(df['Perceived_AI_Dependency'].median())

# %%
df['Anxiety_Level_During_Exams'] =  pd.to_numeric(df['Anxiety_Level_During_Exams'],errors='coerce')

# %%
df['Anxiety_Level_During_Exams'] = df['Anxiety_Level_During_Exams'].fillna(df['Anxiety_Level_During_Exams'].median())

# %%
df['Post_Semester_GPA'] = pd.to_numeric(df['Post_Semester_GPA'],errors='coerce')

# %%
df['Post_Semester_GPA'] = df['Post_Semester_GPA'].fillna(df['Post_Semester_GPA'].median())

# %%
df['Skill_Retention_Score'] = df['Skill_Retention_Score'].fillna(df['Skill_Retention_Score'].median())

# %% [markdown]
# # Type Casting

# %%
df['Anxiety_Level_During_Exams']=df['Anxiety_Level_During_Exams'].astype(int)

# %%
df['Post_Semester_GPA']=df['Post_Semester_GPA'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30777 entries, 0 to 30899
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  30777 non-null  int64
#  1   Major_Category              30777 non-null  object
#  2   Year_of_Study               30777 non-null  object
#  3   Pre_Semester_GPA            30777 non-null  float64
#  4   Weekly_GenAI_Hours          30777 non-null  float64
#  5   Primary_Use_Case            30777 non-null  object
#  6   Prompt_Engineering_Skill    30777 non-null  object
#  7   Tool_Diversity              30777 non-null  float64
#  8   Paid_Subscription           30777 non-null  object
#  9   Traditional_Study_Hours     30777 non-null  float64
#  10  Perceived_AI_Dependency     30777 non-null  float64
#  11  Institutional_Policy        30777 non-null  object
#  12  Anxiety_Level_During_Exams  30777 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   30777.000000      30777.000000        30777.000000    30777.000000
# mean   125031.937941          3.142212            8.556568        2.803165
# std     14462.528136          0.512619            9.486392        1.154319
# min    100001.000000         -1.998000            0.000000        1.000000
# 25%    112473.000000          2.866000            2.640000        2.000000
# 50%    125124.000000          3.207000            5.850000        3.000000
# 75%    137533.000000          3.492000           11.160000        3.000000
# max    150000.000000          5.490000          119.280000        5.000000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# count             30777.000000             30777.000000
# mean                 11.437307                 3.493031
# std                   6.188887                 1.783375
# min                   1.000000                 1.000000
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# ## 1. Univariate Analysis

# %%
# with using ai study time
plt.figure(figsize = (8,6))
sns.histplot(x = 'Weekly_GenAI_Hours' , data = df)
plt.title('Student study Weekly hours using GenAI')
plt.grid()
plt.show()

# %% [markdown]
# ## Observation:
# This is Uni-variate Analysis graph of weekly_GenAI_Hours columns. In this graph there are 3300-3400 students who studied 5-6 hrs using GenAI

# %%
# without used ai study time
plt.figure(figsize = (8,6))
sns.histplot(x = 'Traditional_Study_Hours' , data = df)
plt.title('Student study Weekly hours without using GenAI')
plt.grid()
plt.show()

# %% [markdown]
# ## Observation:
# This is Uni-variate Analysis graph of Traditional_Study_Hours columns. In this graph there are 3300-3400 students who studied 10 hrs without using GenAI

# %%
sns.histplot(x = 'Post_Semester_GPA' , data = df)
plt.title('Students latest semseter GPA')
plt.grid()
plt.show()

# %% [markdown]
# ## Observation:
# This graph shows the Post-Semester GPA distribution of students who use Generative AI tools. Around 3300–3400 students achieved a GPA of approximately 3.4, indicating good academic performance among the students in the dataset.

# %%
sns.histplot(x = 'Anxiety_Level_During_Exams' , data = df)
plt.grid()
plt.title('Student Anxiety Level During Exam')
plt.show()

# %% [markdown]
# ## Observation:
# This is Uni-variate Analysis graph of Anxiety_Level_During_Exams columns. In this graph there are 6800-6900 students who have highest 4 stage of anxiety level.

# %%
sns.histplot(x = 'Burnout_Risk_Level' , data = df)
plt.grid()
plt.title('Student Exhaustion level due to workload/study ')
plt.show()

# %% [markdown]
# ## Observation:
# This is Uni-variate Analysis graph of Burnout_Risk_Level columns. In this graph there are above 14000 students who have moderate burnout level or exhaustion level during exam.

# %%
sns.histplot(x = 'Major_Category' , data = df)
plt.title('Field of study')
plt.grid()
plt.show()

# %% [markdown]
# ## Observation:
# This is Uni-variate Analysis graph of Major_Category columns. In this graph, STEM is the one of the study field in this field more student admitted.

# %% [markdown]
# # Bi-Variate Analysis

# %% [markdown]
# ## Numerical VS Numerical

# %%
sns.scatterplot(x='Weekly_GenAI_Hours',y='Post_Semester_GPA',data=df)
plt.title('Relation Between Weekly_GenAI_Hours and Post_Semester_GPA')
plt.show()

# %% [markdown]
# # Observation:
# This is a Bivariate Analysis visualizing the relationship between Weekly_GenAI_Hours (X-axis) and Post_Semester_GPA (Y-axis).
# In this Graph there are two partition one for the students who got more CGPA that is 4.0 CGPA in less weekly hour that is 40 hrs using GenAI and another is the students who got more CGPA that is 4.0 CGPA in more weekly hours that is 120 hrs using GenAI. But at the end semester CGPA is increase using GenAI.

# %%
sns.scatterplot(x='Weekly_GenAI_Hours',y='Traditional_Study_Hours',data=df)
plt.title('Relation Between Weekly_GenAI_Hours and Traditional_Study_Hours')
plt.show()

# %% [markdown]
# # Observation:
# This is a Bivariate Analysis visualizing the relationship between Weekly_GenAI_Hours (X-axis) and Traditional_Study_Hours (Y-axis).
# This graph is on students weekly hours using GenAI or without GenAI. Here there are three phase, in the first phase students spend same time for study that is 40 hrs using GenAI and 40 hrs using without GenAI, in the second phase students spend more hours for study with GenAI and less hours without using GenAI, in the third phase students spend less hours for study with GenAI and more without GenAI

# %% [markdown]
# ## Categorical Vs Numerical

# %%
sns.barplot(x='Major_Category',y='Post_Semester_GPA',data=df)
plt.title('Compare Major_Category and Post_semester_GPA')
plt.show()

# %% [markdown]
# ## Observation:
# This is a Bivariate Analysis visualizing the relationship between Weekly_GenAI_Hours (X-axis) and Post_Semester_GPA (Y-axis).
# In this graph there are some catogorical for study , almost all category have good CGPA in post semester that is 3.0- 3.5

# %%
sns.barplot(x='Paid_Subscription',y='Weekly_GenAI_Hours',data=df,palette='Set2')
plt.title('Compare Paid_Subscription and Weekly_GenAI_Hours')

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8724\3371541888.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Paid_Subscription',y='Weekly_GenAI_Hours',data=df,palette='Set2')

# %% [markdown]
# ## Observation
# This Bivariate Analysis compares Weekly_GenAI_Hours against Paid_Subscription status. The visualization indicates a positive correlation between subscription status and tool usage; students with a paid GenAI subscription record a higher average number of study hours using GenAI tools compared to students without a subscription.

# %% [markdown]
# ## Categorical VS Categorical

# %%
sns.histplot(x='Major_Category',y='Burnout_Risk_Level',data=df,palette='Set2',multiple="stack")
plt.title('Compare Major_Category and Burnout_Risk_Level')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8724\2978127193.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='Major_Category',y='Burnout_Risk_Level',data=df,palette='Set2',multiple="stack")

# %% [markdown]
# ## Observation:
# This Bivariate Analysis compares Major_Category against Burnout_Risk_Level status. In this graph every category (Business, Arts, STEM, Medical, Humanities) actually shows a mix of Low, Medium, and High burnout levels. The STEM column just happens to have a darker square for "Medium," which means more STEM students are in that category compared to others.

# %% [markdown]
# # Multi-Variate Analysis

# %%
# Select the specific columns for the heatmap
cols_to_plot = ['Tool_Diversity', 'Weekly_GenAI_Hours', 'Post_Semester_GPA']

# Calculate the correlation matrix
correlation_matrix = df[cols_to_plot].corr()

# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_matrix, 
    annot=True,        # Show the correlation values
    cmap='coolwarm',   # Red-Blue color scheme
    fmt=".2f",         # Format to 2 decimal places
    linewidths=0.5
)
 
plt.title('Correlation Heatmap: AI Usage and GPA')
plt.show()

# %% [markdown]
# ## Observation:
# Based on the heatmap:
#
# - **Tool_Diversity and Post_Semester_GPA** have a correlation of 0.02, which is extremely weak positive correlation. This suggests that using a wider variety of AI tools has almost no impact on GPA.
# - **Weekly_GenAI_Hours and Post_Semester_GPA** have a correlation of -0.01, which is essentially no correlation. This indicates that the number of hours spent using GenAI tools does not significantly affect students' GPA.
# - Overall, all correlation values are very close to 0, suggesting no meaningful linear relationship between AI usage metrics (Tool Diversity and Weekly GenAI Hours) and Post-Semester GPA in this dataset.
